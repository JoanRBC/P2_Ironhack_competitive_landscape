# %%
#create the list of schools we want to study
schools = {
    'ironhack': 10828,
    'app-academy': 10525,
    'le-wagon': 10868,
    'ubiqum-code-academy': 11111,
    'udacity': 11118,
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests



def get_comments_school(school):
    #create a regex expressionn that will search for the html tags
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    # makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    # converts json to dataframe
    reviews = pd.DataFrame(data['content']['reviews'])

    # aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('', x)
    #create a column in reviews "review_body" that will be populated with another columns created 'body' that will be remove all the html tags
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    # create a column 'school' with the school
    reviews['school'] = school
    #return the table with all the reviews of a defined school
    return reviews




#list comprehension
comments=[get_comments_school(school) for school in schools.keys()]

comments = pd.concat(comments)

from pandas.io.json import json_normalize


def get_school_info(school, school_id):
    #create the URL for each school
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F' + str(
        school) + '&isDataTarget=false&bootcampId=' + str(
        school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    #create a json fil
    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns=['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website, description, logoUrl]).T
    school_df.columns = ['website', 'description', 'LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school

    # how could you write a similar block of code to the above in order to record the school ID?

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df


locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    a, b, c, d = get_school_info(school, id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)

locations = pd.concat(locations_list)
courses = pd.concat(courses_list)
badges = pd.concat(badges_list)
schools = pd.concat(schools_list)
# Out:
# ironhack
# /Users/guillaumeaubert/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:64: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# app-academy
# le-wagon
# ubiqum-code-academy
# udacity
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    www.lewagon.com
# 0  ubiqum.com/?utm_source=switchup&utm_medium=pla...
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Le Wagon runs imm...
# 0  <span class="truncatable"><p>Ubiqum Code Acade...
# 0  <span class="truncatable"><p>Udacity is a glob...
#
#                                              LogoUrl               school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ubiqum-code-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              udacity
#
#    school_id
# 0      10828
# 0      10525
# 0      10868
# 0      11111
# 0      11118

# %%
schools.head()
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    www.lewagon.com
# 0  ubiqum.com/?utm_source=switchup&utm_medium=pla...
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Le Wagon runs imm...
# 0  <span class="truncatable"><p>Ubiqum Code Acade...
# 0  <span class="truncatable"><p>Udacity is a glob...
#
#                                              LogoUrl               school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ubiqum-code-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              udacity
#
#    school_id
# 0      10828
# 0      10525
# 0      10868
# 0      11111
# 0      11118

# %%
def remove_tags_url(x):
    TAG_RE = re.compile("/.*$")
    return TAG_RE.sub('', x)

def remove_tags_html(x):
    TAG_RE = re.compile(r'<[^>]+>')
    return TAG_RE.sub('', x)

def convert_integer(x):
    if type(x)==float:
        x=int(x)
    else:
        x
    return x


schools['description'] = schools['description'].apply(remove_tags_html)
schools['website'] = schools['website'].apply(remove_tags_url)
schools=schools.drop(['LogoUrl'], axis=1)

# %%
badges['description'] = badges['description'].apply(remove_tags_html)

# %%
#datacleaning
comments['body'] = comments['body'].apply(remove_tags_html)
comments['graduatingYear'].fillna(0, inplace=True)
comments['graduatingYear']
comments['graduatingYear']=comments['graduatingYear'].apply(convert_integer)

# %%
comments
# Out:
#           id            name  anonymous hostProgramName  graduatingYear  \
# 0     266264         William      False            None            2020
# 1     266263  Camille Libert      False            None            2020
# 2     266037       Anonymous       True            None            2020
# 3     266009  Manon Philippe      False            None            2020
# 4     265960    Tim Stephens      False            None            2020
# ...      ...             ...        ...             ...             ...
# 1142  239461     Phil anonio      False            None            2017
# 1143  236598       Anonymous       True            None            2017
# 1144  233529       Anonymous      False            None            2016
# 1145  233782       Anonymous      False    Data Science            2016
# 1146  233333       Anonymous      False            None            2016
#
#      isAlumni                          jobTitle  \
# 0       False               Front-End Developer
# 1       False          Insights Project Manager
# 2        True
# 3       False                          Designer
# 4       False  full stack web developer/teacher
# ...       ...                               ...
# 1142     True                              None
# 1143     True                              None
# 1144     True                              None
# 1145     True                              None
# 1146    False                              None
#
#                                                 tagline  \
# 0     Amazing choice if you're willing to deep dive ...
# 1     Great organisation and adaptability of the cla...
# 2                       Great experience as expected :)
# 3                            A very complete bootcamp !
# 4     Hugely rewarding experience that gave me a job...
# ...                                                 ...
# 1142                                         Worst ever
# 1143                             Introduction to Python
# 1144                                    Can be improved
# 1145                              Intro to data science
# 1146                                       Not great...
#
#                                                    body   createdAt  \
# 0     In a nutshell: great staff, courses in English...    7/9/2020
# 1     Pros:- class organised with exercises, formal ...    7/9/2020
# 2     Excellent choice to get introduced into Data A...    7/3/2020
# 3     I was unconvinced when I joined this formation...    7/2/2020
# 4     Pros: - Learning javascript to the level of a ...    7/1/2020
# ...                                                 ...         ...
# 1142  They are thieves. DO NOT pay them. I made a mi...   11/9/2017
# 1143  Pros: (1) self-paced, (2) context-based, (3) c...   6/26/2017
# 1144  There's a lot of positives about the Udacity f...  12/22/2016
# 1145  I love Udacity. I watch many free online cours...   5/13/2016
# 1146  Support is very limited. Don't think that it's...   2/28/2016
#
#        queryDate                    program             user overallScore  \
# 0     2020-07-09   Web Development Bootcamp  {'image': None}          4.7
# 1     2020-07-09    Data Analytics Bootcamp  {'image': None}          4.7
# 2     2020-07-03    Data Analytics Bootcamp  {'image': None}          5.0
# 3     2020-07-02      UX/UI Design Bootcamp  {'image': None}          4.7
# 4     2020-07-01   Web Development Bootcamp  {'image': None}          4.7
# ...          ...                        ...              ...          ...
# 1142  2017-11-09                       None  {'image': None}          1.0
# 1143  2017-06-26  Intro to Computer Science  {'image': None}          3.0
# 1144  2016-12-22                       None  {'image': None}          3.0
# 1145  2016-05-13  Intro to Computer Science  {'image': None}          5.0
# 1146  2016-02-28                       None  {'image': None}          2.0
#
#      comments overall curriculum jobSupport  \
# 0          []     5.0        5.0        4.0
# 1          []     5.0        5.0        4.0
# 2          []     5.0        5.0        5.0
# 3          []     5.0        5.0        4.0
# 4          []     5.0        4.0        5.0
# ...       ...     ...        ...        ...
# 1142       []     1.0        1.0        1.0
# 1143       []     3.0        4.0        2.0
# 1144       []     3.0        3.0        3.0
# 1145       []     5.0        NaN        NaN
# 1146       []     2.0        NaN        NaN
#
#                                             review_body    school
# 0     In a nutshell: great staff, courses in English...  ironhack
# 1     Pros:- class organised with exercises, formal ...  ironhack
# 2     Excellent choice to get introduced into Data A...  ironhack
# 3     I was unconvinced when I joined this formation...  ironhack
# 4     Pros: - Learning javascript to the level of a ...  ironhack
# ...                                                 ...       ...
# 1142  They are thieves. DO NOT pay them. I made a mi...   udacity
# 1143  Pros: (1) self-paced, (2) context-based, (3) c...   udacity
# 1144  There's a lot of positives about the Udacity f...   udacity
# 1145  I love Udacity. I watch many free online cours...   udacity
# 1146  Support is very limited. Don't think that it's...   udacity
#
# [4768 rows x 20 columns]

# %%
#data
comments=comments.drop(['queryDate'], axis=1)
comments=comments.drop(['user'], axis=1)
comments=comments.drop(['comments'], axis=1)

# %%
comments
# Out:
#           id            name  anonymous hostProgramName  graduatingYear  \
# 0     266264         William      False            None            2020
# 1     266263  Camille Libert      False            None            2020
# 2     266037       Anonymous       True            None            2020
# 3     266009  Manon Philippe      False            None            2020
# 4     265960    Tim Stephens      False            None            2020
# ...      ...             ...        ...             ...             ...
# 1142  239461     Phil anonio      False            None            2017
# 1143  236598       Anonymous       True            None            2017
# 1144  233529       Anonymous      False            None            2016
# 1145  233782       Anonymous      False    Data Science            2016
# 1146  233333       Anonymous      False            None            2016
#
#      isAlumni                          jobTitle  \
# 0       False               Front-End Developer
# 1       False          Insights Project Manager
# 2        True
# 3       False                          Designer
# 4       False  full stack web developer/teacher
# ...       ...                               ...
# 1142     True                              None
# 1143     True                              None
# 1144     True                              None
# 1145     True                              None
# 1146    False                              None
#
#                                                 tagline  \
# 0     Amazing choice if you're willing to deep dive ...
# 1     Great organisation and adaptability of the cla...
# 2                       Great experience as expected :)
# 3                            A very complete bootcamp !
# 4     Hugely rewarding experience that gave me a job...
# ...                                                 ...
# 1142                                         Worst ever
# 1143                             Introduction to Python
# 1144                                    Can be improved
# 1145                              Intro to data science
# 1146                                       Not great...
#
#                                                    body   createdAt  \
# 0     In a nutshell: great staff, courses in English...    7/9/2020
# 1     Pros:- class organised with exercises, formal ...    7/9/2020
# 2     Excellent choice to get introduced into Data A...    7/3/2020
# 3     I was unconvinced when I joined this formation...    7/2/2020
# 4     Pros: - Learning javascript to the level of a ...    7/1/2020
# ...                                                 ...         ...
# 1142  They are thieves. DO NOT pay them. I made a mi...   11/9/2017
# 1143  Pros: (1) self-paced, (2) context-based, (3) c...   6/26/2017
# 1144  There's a lot of positives about the Udacity f...  12/22/2016
# 1145  I love Udacity. I watch many free online cours...   5/13/2016
# 1146  Support is very limited. Don't think that it's...   2/28/2016
#
#                         program overallScore overall curriculum jobSupport  \
# 0      Web Development Bootcamp          4.7     5.0        5.0        4.0
# 1       Data Analytics Bootcamp          4.7     5.0        5.0        4.0
# 2       Data Analytics Bootcamp          5.0     5.0        5.0        5.0
# 3         UX/UI Design Bootcamp          4.7     5.0        5.0        4.0
# 4      Web Development Bootcamp          4.7     5.0        4.0        5.0
# ...                         ...          ...     ...        ...        ...
# 1142                       None          1.0     1.0        1.0        1.0
# 1143  Intro to Computer Science          3.0     3.0        4.0        2.0
# 1144                       None          3.0     3.0        3.0        3.0
# 1145  Intro to Computer Science          5.0     5.0        NaN        NaN
# 1146                       None          2.0     2.0        NaN        NaN
#
#                                             review_body    school
# 0     In a nutshell: great staff, courses in English...  ironhack
# 1     Pros:- class organised with exercises, formal ...  ironhack
# 2     Excellent choice to get introduced into Data A...  ironhack
# 3     I was unconvinced when I joined this formation...  ironhack
# 4     Pros: - Learning javascript to the level of a ...  ironhack
# ...                                                 ...       ...
# 1142  They are thieves. DO NOT pay them. I made a mi...   udacity
# 1143  Pros: (1) self-paced, (2) context-based, (3) c...   udacity
# 1144  There's a lot of positives about the Udacity f...   udacity
# 1145  I love Udacity. I watch many free online cours...   udacity
# 1146  Support is very limited. Don't think that it's...   udacity
#
# [4768 rows x 17 columns]

# %%
schools=schools.set_index('website')

# %%
schools.to_csv('/Users/guillaumeaubert/Documents/Ironhack/Module1/Week2/Day2_SQL_Advanced/schools.csv')
