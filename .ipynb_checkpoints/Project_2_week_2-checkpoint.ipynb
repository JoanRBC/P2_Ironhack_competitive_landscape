# %%
#create the list of schools we want to study
schools = {
    'ironhack': 10828,
    'app-academy': 10525,
    'le-wagon': 10868,
    'ubiqum-code-academy': 11111,
    'udacity': 11118,
}

import re
import pandas as pd
from pandas.io.json import json_normalize
import requests


def get_comments_school(school):
    #create a regex expressionn that will search for the html tags
    TAG_RE = re.compile(r'<[^>]+>')
    # defines url to make api call to data -> dynamic with school if you want to scrape competition
    url = "https://www.switchup.org/chimera/v1/school-review-list?mainTemplate=school-review-list&path=%2Fbootcamps%2F" + school + "&isDataTarget=false&page=3&perPage=10000&simpleHtml=true&truncationLength=250"
    # makes get request and converts answer to json
    # url defines the page of all the information, request is made, and information is returned to data variable
    data = requests.get(url).json()
    # converts json to dataframe
    reviews = pd.DataFrame(data['content']['reviews'])

    # aux function to apply regex and remove tags
    def remove_tags(x):
        return TAG_RE.sub('', x)
    #create a column in reviews "review_body" that will be populated with another columns created 'body' that will be remove all the html tags
    reviews['review_body'] = reviews['body'].apply(remove_tags)
    # create a column 'school' with the school
    reviews['school'] = school
    #return the table with all the reviews of a defined school
    return reviews



#list comprehension
comments=[get_comments_school(school) for school in schools.keys()]

comments = pd.concat(comments)

from pandas.io.json import json_normalize


def get_school_info(school, school_id):
    #create the URL for each school
    url = 'https://www.switchup.org/chimera/v1/bootcamp-data?mainTemplate=bootcamp-data%2Fdescription&path=%2Fbootcamps%2F' + str(
        school) + '&isDataTarget=false&bootcampId=' + str(
        school_id) + '&logoTag=logo&truncationLength=250&readMoreOmission=...&readMoreText=Read%20More&readLessText=Read%20Less'

    #create a json fil
    data = requests.get(url).json()

    data.keys()

    courses = data['content']['courses']
    courses_df = pd.DataFrame(courses, columns=['courses'])

    locations = data['content']['locations']
    locations_df = json_normalize(locations)

    badges_df = pd.DataFrame(data['content']['meritBadges'])

    website = data['content']['webaddr']
    description = data['content']['description']
    logoUrl = data['content']['logoUrl']
    school_df = pd.DataFrame([website, description, logoUrl]).T
    school_df.columns = ['website', 'description', 'LogoUrl']

    locations_df['school'] = school
    courses_df['school'] = school
    badges_df['school'] = school
    school_df['school'] = school

    # how could you write a similar block of code to the above in order to record the school ID?

    locations_df['school_id'] = school_id
    courses_df['school_id'] = school_id
    badges_df['school_id'] = school_id
    school_df['school_id'] = school_id

    return locations_df, courses_df, badges_df, school_df


locations_list = []
courses_list = []
badges_list = []
schools_list = []

for school, id in schools.items():
    print(school)
    a, b, c, d = get_school_info(school, id)

    locations_list.append(a)
    courses_list.append(b)
    badges_list.append(c)
    schools_list.append(d)

locations = pd.concat(locations_list)
locations.head(10)

courses = pd.concat(courses_list)
courses.head(10)

badges = pd.concat(badges_list)
badges.head(10)

schools = pd.concat(schools_list)
schools



print(schools.head())
# Out:
# ironhack
# C:\Users\joanr\anaconda3\lib\site-packages\ipykernel_launcher.py:62: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# app-academy
# le-wagon
# ubiqum-code-academy
# udacity
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    www.lewagon.com
# 0  ubiqum.com/?utm_source=switchup&utm_medium=pla...
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Le Wagon runs imm...
# 0  <span class="truncatable"><p>Ubiqum Code Acade...
# 0  <span class="truncatable"><p>Udacity is a glob...
#
#                                              LogoUrl               school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ubiqum-code-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              udacity
#
#    school_id
# 0      10828
# 0      10525
# 0      10868
# 0      11111
# 0      11118

# %% [markdown]
# ### Null values in every dataframe

# %%
courses.isnull().sum()
# Out:
# courses      0
# school       0
# school_id    0
# dtype: int64

# %%
schools.isnull().sum()
# Out:
# website        0
# description    0
# LogoUrl        0
# school         0
# school_id      0
# dtype: int64

# %%
locations.isnull().sum()
# Out:
# id                 0
# description        0
# country.id         3
# country.name       3
# country.abbrev     3
# city.id            3
# city.name          3
# city.keyword       3
# state.id          53
# state.name        53
# state.abbrev      53
# state.keyword     56
# school             0
# school_id          0
# dtype: int64

# %%
comments.isnull().sum()
# Out:
# id                    0
# name                  0
# anonymous             0
# hostProgramName    4484
# graduatingYear        8
# isAlumni             12
# jobTitle           3318
# tagline               1
# body                  0
# createdAt             0
# queryDate             0
# program             632
# user                  0
# overallScore         11
# comments              0
# overall              13
# curriculum          121
# jobSupport          339
# review_body           0
# school                0
# dtype: int64

# %%
badges.isnull().sum()
# Out:
# name           0
# keyword        0
# description    0
# school         0
# school_id      0
# dtype: int64

# %% [markdown]
# ### Shape of every dataframe

# %%
courses.shape
# Out:
# (48, 3)

# %%
schools.shape
# Out:
# (5, 5)

# %%
locations.shape
# Out:
# (59, 14)

# %%
comments.shape
# Out:
# (4768, 20)

# %%
badges.shape
# Out:
# (7, 5)

# %% [markdown]
# ### Dataframe tables

# %%
courses
# Out:
#                                 courses               school  school_id
# 0               Data Analytics Bootcamp             ironhack      10828
# 1              Data Analytics Part-Time             ironhack      10828
# 2                 UX/UI Design Bootcamp             ironhack      10828
# 3                UX/UI Design Part-Time             ironhack      10828
# 4              Web Development Bootcamp             ironhack      10828
# 5             Web Development Part-Time             ironhack      10828
# 0                         Bootcamp Prep          app-academy      10525
# 1    Software Engineer Track: In-Person          app-academy      10525
# 2       Software Engineer Track: Online          app-academy      10525
# 0    Web Development Course - Full-Time             le-wagon      10868
# 1    Web Development Course - Part-Time             le-wagon      10868
# 2              Data Science - Full-Time             le-wagon      10868
# 0     Data Analytics & Machine Learning  ubiqum-code-academy      11111
# 1             Web Development with Java  ubiqum-code-academy      11111
# 2       Web Development with JavaScript  ubiqum-code-academy      11111
# 0            AI Programming with Python              udacity      11118
# 1                    Al Product Manager              udacity      11118
# 2                        Android Basics              udacity      11118
# 3                     Android Developer              udacity      11118
# 4               Artificial Intelligence              udacity      11118
# 5   Artificial Intelligence for Trading              udacity      11118
# 6                  Blockchain Developer              udacity      11118
# 7                    Business Analytics              udacity      11118
# 8                                   C++              udacity      11118
# 9                Cloud Dev Ops Engineer              udacity      11118
# 10                      Cloud Developer              udacity      11118
# 11                      Computer Vision              udacity      11118
# 12                         Data Analyst              udacity      11118
# 13                        Data Engineer              udacity      11118
# 14       Data Structures and Algorithms              udacity      11118
# 15                   Data Visualization              udacity      11118
# 16                        Deep Learning              udacity      11118
# 17          Deep Reinforcement Learning              udacity      11118
# 18                    Digital Marketing              udacity      11118
# 19              Front End Web Developer              udacity      11118
# 20             Full Stack Web Developer              udacity      11118
# 21     Introduction to Machine Learning              udacity      11118
# 22          Introduction to Programming              udacity      11118
# 23                        iOS Developer              udacity      11118
# 24                       Java Developer              udacity      11118
# 25            Machine Learning Engineer              udacity      11118
# 26                  Marketing Analytics              udacity      11118
# 27          Natural Language Processing              udacity      11118
# 28    Predictive Analytics for Business              udacity      11118
# 29                                React              udacity      11118
# 30           Robotics Software Engineer              udacity      11118
# 31            Self-Driving Car Engineer              udacity      11118
# 32                          UX Designer              udacity      11118

# %%
schools
# Out:
#                                              website  \
# 0                                www.ironhack.com/en
# 0                                      appacademy.io
# 0                                    www.lewagon.com
# 0  ubiqum.com/?utm_source=switchup&utm_medium=pla...
# 0  www.udacity.com/?utm_source=switchup&utm_mediu...
#
#                                          description  \
# 0  <span class="truncatable"><p>Ironhack is a glo...
# 0  <span class="truncatable"><p>App Academy is a ...
# 0  <span class="truncatable"><p>Le Wagon runs imm...
# 0  <span class="truncatable"><p>Ubiqum Code Acade...
# 0  <span class="truncatable"><p>Udacity is a glob...
#
#                                              LogoUrl               school  \
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             ironhack
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...          app-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...             le-wagon
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...  ubiqum-code-academy
# 0  https://d92mrp7hetgfk.cloudfront.net/images/si...              udacity
#
#    school_id
# 0      10828
# 0      10525
# 0      10868
# 0      11111
# 0      11118

# %%
locations
# Out:
#        id                       description  country.id          country.name  \
# 0   15901                   Berlin, Germany        57.0               Germany
# 1   16022               Mexico City, Mexico        29.0                Mexico
# 2   16086            Amsterdam, Netherlands        59.0           Netherlands
# 3   16088                 Sao Paulo, Brazil        42.0                Brazil
# 4   16109                     Paris, France        38.0                France
# 5   16375          Miami, FL, United States         1.0         United States
# 6   16376                     Madrid, Spain        12.0                 Spain
# 7   16377                  Barcelona, Spain        12.0                 Spain
# 8   16709                  Lisbon, Portugal        28.0              Portugal
# 9   17233                            Online         NaN                   NaN
# 0   15704  San Francisco, CA, United States         1.0         United States
# 1   15705  New York City, NY, United States         1.0         United States
# 2   15862                            Online         NaN                   NaN
# 0   15803              Melbourne, Australia        20.0             Australia
# 1   15904               Casablanca, Morocco        44.0               Morocco
# 2   15906           Buenos Aires, Argentina        60.0             Argentina
# 3   15964                 Brussels, Belgium        46.0               Belgium
# 4   15979                      Milan, Italy        39.0                 Italy
# 5   15996                    Chengdu, China        15.0                 China
# 6   16039               Mexico City, Mexico        29.0                Mexico
# 7   16049            Amsterdam, Netherlands        59.0           Netherlands
# 8   16106                 Sao Paulo, Brazil        42.0                Brazil
# 9   16124                  Barcelona, Spain        12.0                 Spain
# 10  16145                  Bordeaux, France        38.0                France
# 11  16146               Copenhagen, Denmark        47.0               Denmark
# 12  16147                     Lille, France        38.0                France
# 13  16148                  Lisbon, Portugal        28.0              Portugal
# 14  16149                   Bali, Indonesia        35.0             Indonesia
# 15  16150                    Nantes, France        38.0                France
# 16  16274           Rio de Janeiro , Brazil        42.0                Brazil
# 17  16275                 Marseille, France        38.0                France
# 18  16282                  Montreal, Canada         2.0                Canada
# 19  16283                   Shanghai, China        15.0                 China
# 20  16307            Belo Horizonte, Brazil        42.0                Brazil
# 21  16407                      Tokyo, Japan        48.0                 Japan
# 22  16408                      Lyon, France        38.0                France
# 23  16478                  Tel Aviv, Israel         5.0                Israel
# 24  16570                      Kyoto, Japan        48.0                 Japan
# 25  16765                   Berlin, Germany        57.0               Germany
# 26  16767                     Paris, France        38.0                France
# 27  16775                   Shenzhen, China        15.0                 China
# 28  16776             Lausanne, Switzerland        32.0           Switzerland
# 29  16800                     Madrid, Spain        12.0                 Spain
# 30  16804                      Oslo, Norway        52.0                Norway
# 31  16805                    Rennes, France        38.0                France
# 32  16936              Singapore, Singapore        56.0             Singapore
# 33  16967                   London, England        61.0               England
# 34  16968                       Rome, Italy        39.0                 Italy
# 35  17128                 Stockholm, Sweden        37.0                Sweden
# 36  17129                      Seoul, Korea        55.0           South Korea
# 37  17157                  Istanbul, Turkey       237.0                Turkey
# 38  17188                   Toronto, Canada         2.0                Canada
# 39  17314       Dubai, United Arab Emirates        34.0  United Arab Emirates
# 0   15913                   Berlin, Germany        57.0               Germany
# 1   16118                  Barcelona, Spain        12.0                 Spain
# 2   16155            Amsterdam, Netherlands        59.0           Netherlands
# 3   16577                     Madrid, Spain        12.0                 Spain
# 4   17192                  Lisbon, Portugal        28.0              Portugal
# 0   15807                            Online         NaN                   NaN
#
#    country.abbrev  city.id        city.name    city.keyword  state.id  \
# 0              DE  31156.0           Berlin          berlin       NaN
# 1              MX  31175.0      Mexico City     mexico-city       NaN
# 2              NL  31168.0        Amsterdam       amsterdam       NaN
# 3              BR  31121.0        Sao Paulo       sao-paulo       NaN
# 4              FR  31136.0            Paris           paris       NaN
# 5              US     31.0            Miami           miami      11.0
# 6              ES  31052.0           Madrid          madrid       NaN
# 7              ES  31170.0        Barcelona       barcelona       NaN
# 8              PT  31075.0           Lisbon          lisbon       NaN
# 9             NaN      NaN              NaN             NaN       1.0
# 0              US     13.0    San Francisco   san-francisco       6.0
# 1              US   1507.0    New York City   new-york-city      34.0
# 2             NaN      NaN              NaN             NaN       1.0
# 0              AU  31174.0        Melbourne       melbourne       NaN
# 1              MA  31119.0       Casablanca      casablanca       NaN
# 2              AR  31171.0     Buenos Aires    buenos-aires       NaN
# 3              BE  31125.0         Brussels        brussels       NaN
# 4              IT  31107.0            Milan           milan       NaN
# 5              CN  31126.0          Chengdu         chengdu       NaN
# 6              MX  31175.0      Mexico City     mexico-city       NaN
# 7              NL  31168.0        Amsterdam       amsterdam       NaN
# 8              BR  31121.0        Sao Paulo       sao-paulo       NaN
# 9              ES  31170.0        Barcelona       barcelona       NaN
# 10             FR  31124.0         Bordeaux        bordeaux       NaN
# 11             DK  31127.0       Copenhagen      copenhagen       NaN
# 12             FR  31128.0            Lille           lille       NaN
# 13             PT  31075.0           Lisbon          lisbon       NaN
# 14             ID  31169.0             Bali            bali       NaN
# 15             FR  31130.0           Nantes          nantes       NaN
# 16             BR  31131.0  Rio de Janeiro   rio-de-janeiro       NaN
# 17             FR  31129.0        Marseille       marseille       NaN
# 197  <span class="truncatable"><p></p><p>Je viens t...  3/18/2020  2020-03-18
# 198  <span class="truncatable"><p>I researched a nu...  3/18/2020  2020-03-18
# 199  <span class="truncatable"><p>Le Wagon, what an...  3/11/2020  2020-03-11
# 200  <span class="truncatable"><p>I signed up to Le...  3/11/2020  2020-03-11
# 201  <span class="truncatable"><p>This fullstack pr...  3/11/2020  2020-03-11
# 202  <span class="truncatable"><p>As an engineer, I...  2/26/2020  2020-02-26
# 203  <span class="truncatable"><p>Learning how to c...  2/24/2020  2020-02-24
# 204  <span class="truncatable"><p>Hello My Name is ...  2/24/2020  2020-02-24
# 205  <span class="truncatable"><p>I joined the prog...  2/24/2020  2020-02-24
# 206  <span class="truncatable"><p>I initially signe...  2/20/2020  2020-02-20
# 207  <span class="truncatable"><p>From cook to deve...  2/20/2020  2020-02-20
# 208  <span class="truncatable"><p>Story of my life<...  2/20/2020  2020-02-20
#
#                program             user overallScore comments overall  \
# 159  FullStack program  {'image': None}          4.3       []     5.0
# 160  FullStack program  {'image': None}          4.7       []     5.0
# 161  FullStack program  {'image': None}          4.7       []     5.0
# 162  FullStack program  {'image': None}          5.0       []     5.0
# 163  FullStack program  {'image': None}          5.0       []     5.0
# 164  FullStack program  {'image': None}          5.0       []     5.0
# 165  FullStack program  {'image': None}          5.0       []     5.0
# 166  FullStack program  {'image': None}          5.0       []     5.0
# 167  FullStack program  {'image': None}          5.0       []     5.0
# 168  FullStack program  {'image': None}          4.7       []     5.0
# 169  FullStack program  {'image': None}          4.7       []     5.0
# 170  FullStack program  {'image': None}          5.0       []     5.0
# 171  FullStack program  {'image': None}          5.0       []     5.0
# 172  FullStack program  {'image': None}          5.0       []     5.0
# 173  FullStack program  {'image': None}          5.0       []     5.0
# 174  FullStack program  {'image': None}          5.0       []     5.0
# 175  FullStack program  {'image': None}          5.0       []     5.0
# 176  FullStack program  {'image': None}          5.0       []     5.0
# 177  FullStack program  {'image': None}          5.0       []     5.0
# 178  FullStack program  {'image': None}          5.0       []     5.0
# 179  FullStack program  {'image': None}          5.0       []     5.0
# 180  FullStack program  {'image': None}          5.0       []     5.0
# 181  FullStack program  {'image': None}          4.7       []     5.0
# 182  FullStack program  {'image': None}          5.0       []     5.0
# 183  FullStack program  {'image': None}          5.0       []     5.0
# 184  FullStack program  {'image': None}          5.0       []     5.0
# 185  FullStack program  {'image': None}          4.7       []     5.0
# 186  FullStack program  {'image': None}          4.7       []     5.0
# 187  FullStack program  {'image': None}          5.0       []     5.0
# 188  FullStack program  {'image': None}          4.7       []     5.0
# 189  FullStack program  {'image': None}          5.0       []     5.0
# 190  FullStack program  {'image': None}          5.0       []     5.0
# 191  FullStack program  {'image': None}          4.7       []     5.0
# 192  FullStack program  {'image': None}          5.0       []     5.0
# 193  FullStack program  {'image': None}          4.7       []     5.0
# 194  FullStack program  {'image': None}          5.0       []     5.0
# 195  FullStack program  {'image': None}          5.0       []     5.0
# 196  FullStack program  {'image': None}          5.0       []     5.0
# 197                     {'image': None}          5.0       []     5.0
# 198  FullStack program  {'image': None}          5.0       []     5.0
# 199  FullStack program  {'image': None}          5.0       []     5.0
# 200  FullStack program  {'image': None}          5.0       []     5.0
# 201  FullStack program  {'image': None}          5.0       []     5.0
# 202  FullStack program  {'image': None}          5.0       []     5.0
# 203  FullStack program  {'image': None}          5.0       []     5.0
# 204  FullStack program  {'image': None}          5.0       []     5.0
# 205  FullStack program  {'image': None}          5.0       []     5.0
# 206  FullStack program  {'image': None}          5.0       []     5.0
# 207  FullStack program  {'image': None}          5.0       []     5.0
# 208  FullStack program  {'image': None}          5.0       []     5.0
#
#     curriculum jobSupport                                        review_body  \
# 159        5.0        3.0  My choice to join Le Wagon’s 9-week intensive ...
# 160        5.0        4.0  I was a bit worried before starting Le Wagon t...
# 161        5.0        4.0  After working a few years in human resourcing ...
# 162        5.0        5.0  Before Le Wagon I was an Engineer with no real...
# 163        5.0        5.0  Before starting Le Wagon I was studying engine...
# 164        5.0        5.0  - what you did before Le Wagon I was/still am ...
# 165        5.0        5.0  9 hard-working-fast-paced weeks. I need to say...
# 166        5.0        5.0  My experience in the bootcamp was excellent. T...
# 167        5.0        5.0  Le Wagon Tokyo was such an amazing 9-week expe...
# 168        5.0        4.0  Before starting bootcamp, I had no experience ...
# 169        5.0        4.0  At the time I came across Le Wagon, I had just...
# 170        5.0        5.0  I started Le Wagon with no dev background at a...
# 171        5.0        5.0  After working as sales operations manager at a...
# 172        5.0        5.0  I joined Le Wagon Tokyo because I need to lear...
# 173        5.0        5.0  From the first day to the last I enjoyed every...
# 174        5.0        5.0  Without knowing anything about coding i end up...
# 175        5.0        5.0  Let be honest, this program is hard, freaking ...
# 176        5.0        5.0  I joined Le Wagon in 2020. It was a tough 9 we...
# 177        5.0        5.0  The most amazing bootcamp. Is really hard a lo...
# 178        5.0        5.0  Le Wagon makes learning to code accessible to ...
# 179        5.0        5.0  What I did before: I was a student in Business...
# 180        5.0        5.0  I completed Le Wagon course in March 2020. Bef...
# 181        5.0        4.0  Before I attended LeWagon I had worked as a mo...
# 182        5.0        5.0  Before joining Le Wagon, I was in the marketin...
# 183        5.0        5.0  I've just completed the nine week Le Wagon web...
# 184        5.0        5.0  Wow, what an incredibly challenging, rewarding...
# 185        5.0        4.0  Formerly a Product Manager and consultant in t...
# 186        5.0        4.0  Prior to enrolling in the Le Wagon bootcamp I ...
# 187        5.0        5.0  After 10 years running pubs in and around Lond...
# 188        5.0        4.0  I have completed Le Wagon Montreal coding boot...
# 189        5.0        5.0  I worked in various commercial roles over the ...
# 190        5.0        5.0  Throughout my undergraduate degree in Business...
# 191        5.0        4.0  Before starting le Wagon, I was working in a s...
# 192        5.0        5.0  Personal BackgroundI joined Le Wagon because I...
# 193        5.0        4.0  As I was finishing my studies at UFRJ as a Gra...
# 194        5.0        5.0  I wanted to change my career path and coming f...
# 195        5.0        5.0  J’ai longtemps cherché pourquoi j’étais faite....
# 196        5.0        5.0  Je viens tout juste de terminer le bootcamp du...
# 197        5.0        5.0  Je viens tout juste de terminer le bootcamp du...
# 198        5.0        5.0  I researched a number of options before choosi...
# 199        5.0        5.0  Le Wagon, what an adventure! I did Le Wagon in...
# 200        5.0        5.0  I signed up to Le Wagon after having heard ver...
# 201        5.0        5.0  This fullstack program is a 9 week program whi...
# 202        5.0        5.0  As an engineer, I already had some programming...
# 203        5.0        5.0  Learning how to code had always been a dream -...
# 204        5.0        5.0  Hello My Name is Felipe, and i am a former Stu...
# 205        5.0        5.0  I joined the program with very high expectatio...
# 206        5.0        5.0  I initially signed up to le wagon to get to kn...
# 207        5.0        5.0  From cook to developer in 2 months, it seemed ...
# 208        5.0        5.0  Story of my lifeI have always been passionate ...
#
#        school
# 159  le-wagon
# 160  le-wagon
# 161  le-wagon
# 162  le-wagon
# 163  le-wagon
# 164  le-wagon
# 165  le-wagon
# 166  le-wagon
# 167  le-wagon
# 168  le-wagon
# 169  le-wagon
# 170  le-wagon
# 171  le-wagon
# 172  le-wagon
# 173  le-wagon
# 174  le-wagon
# 175  le-wagon
# 176  le-wagon
# 177  le-wagon
# 178  le-wagon
# 179  le-wagon
# 180  le-wagon
# 181  le-wagon
# 182  le-wagon
# 183  le-wagon
# 184  le-wagon
# 185  le-wagon
# 186  le-wagon
# 187  le-wagon
# 188  le-wagon
# 189  le-wagon
# 190  le-wagon
# 191  le-wagon
# 192  le-wagon
# 193  le-wagon
# 194  le-wagon
# 195  le-wagon
# 196  le-wagon
# 197  le-wagon
# 198  le-wagon
# 199  le-wagon
# 200  le-wagon
# 201  le-wagon
# 202  le-wagon
# 203  le-wagon
# 204  le-wagon
# 205  le-wagon
# 206  le-wagon
# 207  le-wagon
# 208  le-wagon

# %%
badges
# Out:
#                 name            keyword  \
# 0   Available Online   available_online
# 1  Verified Outcomes  verified_outcomes
# 2   Flexible Classes   flexible_classes
# 0   Available Online   available_online
# 1      Job Guarantee      job_guarantee
# 0   Flexible Classes   flexible_classes
# 0   Flexible Classes   flexible_classes
#
#                                          description               school  \
# 0          <p>School offers fully online courses</p>             ironhack
# 1  <p>School publishes a third-party verified out...             ironhack
# 2  <p>School offers part-time and evening classes...             ironhack
# 0          <p>School offers fully online courses</p>          app-academy
# 1             <p>School guarantees job placement</p>          app-academy
# 0  <p>School offers part-time and evening classes...             le-wagon
# 0  <p>School offers part-time and evening classes...  ubiqum-code-academy
#
#    school_id
# 0      10828
# 1      10828
# 2      10828
# 0      10525
# 1      10525
# 0      10868
# 0      11111

# %% [markdown]
# ### Data insights

# %%
set(courses['courses'].unique())
# Out:
# {'AI Programming with Python',
#  'Al Product Manager',
#  'Android Basics',
#  'Android Developer',
#  'Artificial Intelligence',
#  'Artificial Intelligence for Trading',
#  'Blockchain Developer',
#  'Bootcamp Prep',
#  'Business Analytics',
#  'C++',
#  'Cloud Dev Ops Engineer',
#  'Cloud Developer',
#  'Computer Vision',
#  'Data Analyst',
#  'Data Analytics & Machine Learning',
#  'Data Analytics Bootcamp',
#  'Data Analytics Part-Time',
#  'Data Engineer',
#  'Data Science - Full-Time',
#  'Data Structures and Algorithms',
#  'Data Visualization',
#  'Deep Learning',
#  'Deep Reinforcement Learning',
#  'Digital Marketing',
#  'Front End Web Developer',
#  'Full Stack Web Developer',
#  'Introduction to Machine Learning',
#  'Introduction to Programming',
#  'Java Developer',
#  'Machine Learning Engineer',
#  'Marketing Analytics',
#  'Natural Language Processing',
#  'Predictive Analytics for Business',
#  'React',
#  'Robotics Software Engineer',
#  'Self-Driving Car Engineer',
#  'Software Engineer Track: In-Person',
#  'Software Engineer Track: Online',
#  'UX Designer',
#  'UX/UI Design Bootcamp',
#  'UX/UI Design Part-Time',
#  'Web Development Bootcamp',
#  'Web Development Course - Full-Time',
#  'Web Development Course - Part-Time',
#  'Web Development Part-Time',
#  'Web Development with Java',
#  'Web Development with JavaScript',
#  'iOS Developer'}

# %%
mydict = {}

for x in courses['courses'].unique():
    if x not in mydict.keys():
        mydict[x] = 0
    else:
        continue
mydict

def word_finder(keys):
    global mydict
    
    a = set(['data', 'analytics', 'analyst', 'science'])
    b = set(['web', 'development', 'software', 'developer'])
    c = set(['UX', 'UI', 'design', 'designer'])
    d = set(['online', 'remote'])

    for key in keys:     
        if len(a.intersection(set(key.lower().split(" ")))) != 0 :
            mydict[key] = 'data analysis/data science' + ' related course'
            #break
        elif len(b.intersection(set(key.lower().split(" ")))) != 0 :
            mydict[key] = 'web development' + ' related course'
            #break
        elif len(c.intersection(set(key.lower().split(" ")))) != 0 :
            mydict[key] = 'UX/UI Design' + ' related course'
            #break
        elif len(d.intersection(set(key.lower().split(" ")))) != 0 :
            mydict[key] = 'online course'
            #break
        else:
            mydict[key] = 'other courses'      
            
    return mydict
        
word_finder(list(mydict.keys()))
# Out:
# {'Data Analytics Bootcamp': 'data analysis/data science related course',
#  'Data Analytics Part-Time': 'data analysis/data science related course',
#  'UX/UI Design Bootcamp': 'UX/UI Design related course',
#  'UX/UI Design Part-Time': 'UX/UI Design related course',
#  'Web Development Bootcamp': 'web development related course',
#  'Web Development Part-Time': 'web development related course',
#  'Bootcamp Prep': 'other courses',
#  'Software Engineer Track: In-Person': 'web development related course',
#  'Software Engineer Track: Online': 'web development related course',
#  'Web Development Course - Full-Time': 'web development related course',
#  'Web Development Course - Part-Time': 'web development related course',
#  'Data Science - Full-Time': 'data analysis/data science related course',
#  'Data Analytics & Machine Learning': 'data analysis/data science related course',
#  'Web Development with Java': 'web development related course',
#  'Web Development with JavaScript': 'web development related course',
#  'AI Programming with Python': 'other courses',
#  'Al Product Manager': 'other courses',
#  'Android Basics': 'other courses',
#  'Android Developer': 'web development related course',
#  'Artificial Intelligence': 'other courses',
#  'Artificial Intelligence for Trading': 'other courses',
#  'Blockchain Developer': 'web development related course',
#  'Business Analytics': 'data analysis/data science related course',
#  'C++': 'other courses',
#  'Cloud Dev Ops Engineer': 'other courses',
#  'Cloud Developer': 'web development related course',
#  'Computer Vision': 'other courses',
#  'Data Analyst': 'data analysis/data science related course',
#  'Data Engineer': 'data analysis/data science related course',
#  'Data Structures and Algorithms': 'data analysis/data science related course',
#  'Data Visualization': 'data analysis/data science related course',
#  'Deep Learning': 'other courses',
#  'Deep Reinforcement Learning': 'other courses',
#  'Digital Marketing': 'other courses',
#  'Front End Web Developer': 'web development related course',
#  'Full Stack Web Developer': 'web development related course',
#  'Introduction to Machine Learning': 'other courses',
#  'Introduction to Programming': 'other courses',
#  'iOS Developer': 'web development related course',
#  'Java Developer': 'web development related course',
#  'Machine Learning Engineer': 'other courses',
#  'Marketing Analytics': 'data analysis/data science related course',
#  'Natural Language Processing': 'other courses',
#  'Predictive Analytics for Business': 'data analysis/data science related course',
#  'React': 'other courses',
#  'Robotics Software Engineer': 'web development related course',
#  'Self-Driving Car Engineer': 'other courses',
#  'UX Designer': 'UX/UI Design related course'}

# %%
global mydict
set(mydict.values())
# Out:
# {'UX/UI Design related course',
#  'data analysis/data science related course',
#  'other courses',
#  'web development related course'}

# %% [markdown]
# ### Creating the new table

# %%
courses
# Out:
#                                 courses               school  school_id  \
# 0               Data Analytics Bootcamp             ironhack      10828
# 1              Data Analytics Part-Time             ironhack      10828
# 2                 UX/UI Design Bootcamp             ironhack      10828
# 3                UX/UI Design Part-Time             ironhack      10828
# 4              Web Development Bootcamp             ironhack      10828
# 5             Web Development Part-Time             ironhack      10828
# 0                         Bootcamp Prep          app-academy      10525
# 1    Software Engineer Track: In-Person          app-academy      10525
# 2       Software Engineer Track: Online          app-academy      10525
# 0    Web Development Course - Full-Time             le-wagon      10868
# 1    Web Development Course - Part-Time             le-wagon      10868
# 2              Data Science - Full-Time             le-wagon      10868
# 0     Data Analytics & Machine Learning  ubiqum-code-academy      11111
# 1             Web Development with Java  ubiqum-code-academy      11111
# 2       Web Development with JavaScript  ubiqum-code-academy      11111
# 0            AI Programming with Python              udacity      11118
# 1                    Al Product Manager              udacity      11118
# 2                        Android Basics              udacity      11118
# 3                     Android Developer              udacity      11118
# 4               Artificial Intelligence              udacity      11118
# 5   Artificial Intelligence for Trading              udacity      11118
# 6                  Blockchain Developer              udacity      11118
# 7                    Business Analytics              udacity      11118
# 8                                   C++              udacity      11118
# 9                Cloud Dev Ops Engineer              udacity      11118
# 10                      Cloud Developer              udacity      11118
# 11                      Computer Vision              udacity      11118
# 12                         Data Analyst              udacity      11118
# 13                        Data Engineer              udacity      11118
# 14       Data Structures and Algorithms              udacity      11118
# 15                   Data Visualization              udacity      11118
# 16                        Deep Learning              udacity      11118
# 17          Deep Reinforcement Learning              udacity      11118
# 18                    Digital Marketing              udacity      11118
# 19              Front End Web Developer              udacity      11118
# 20             Full Stack Web Developer              udacity      11118
# 21     Introduction to Machine Learning              udacity      11118
# 22          Introduction to Programming              udacity      11118
# 23                        iOS Developer              udacity      11118
# 24                       Java Developer              udacity      11118
# 25            Machine Learning Engineer              udacity      11118
# 26                  Marketing Analytics              udacity      11118
# 27          Natural Language Processing              udacity      11118
# 28    Predictive Analytics for Business              udacity      11118
# 29                                React              udacity      11118
# 30           Robotics Software Engineer              udacity      11118
# 31            Self-Driving Car Engineer              udacity      11118
# 32                          UX Designer              udacity      11118
#
#                              courses by group
# 0   data analysis/data science related course
# 1   data analysis/data science related course
# 2                 UX/UI Design related course
# 3                 UX/UI Design related course
# 4              web development related course
# 5              web development related course
# 0                               other courses
# 1                               other courses
# 2                               online course
# 0              web development related course
# 1              web development related course
# 2   data analysis/data science related course
# 0   data analysis/data science related course
# 1              web development related course
# 2              web development related course
# 0                               other courses
# 1                               other courses
# 2                               other courses
# 3                               other courses
# 4                               other courses
# 5                               other courses
# 6                               other courses
# 7   data analysis/data science related course
# 8                               other courses
# 9                               other courses
# 10                              other courses
# 11                              other courses
# 12  data analysis/data science related course
# 13  data analysis/data science related course
# 14  data analysis/data science related course
# 15  data analysis/data science related course
# 16                              other courses
# 17                              other courses
# 18                              other courses
# 19             web development related course
# 20             web development related course
# 21                              other courses
# 22                              other courses
# 23                              other courses
# 24                              other courses
# 25                              other courses
# 26  data analysis/data science related course
# 27                              other courses
# 28  data analysis/data science related course
# 29                              other courses
# 30                              other courses
# 31                              other courses
# 32                              other courses

# %%
a = courses['courses']
courses['courses by group'] = a #create a new column

# %%
courses
# Out:
#                                 courses               school  school_id  \
# 0               Data Analytics Bootcamp             ironhack      10828
# 1              Data Analytics Part-Time             ironhack      10828
# 2                 UX/UI Design Bootcamp             ironhack      10828
# 3                UX/UI Design Part-Time             ironhack      10828
# 4              Web Development Bootcamp             ironhack      10828
# 5             Web Development Part-Time             ironhack      10828
# 0                         Bootcamp Prep          app-academy      10525
# 1    Software Engineer Track: In-Person          app-academy      10525
# 2       Software Engineer Track: Online          app-academy      10525
# 0    Web Development Course - Full-Time             le-wagon      10868
# 1    Web Development Course - Part-Time             le-wagon      10868
# 2              Data Science - Full-Time             le-wagon      10868
# 0     Data Analytics & Machine Learning  ubiqum-code-academy      11111
# 1             Web Development with Java  ubiqum-code-academy      11111
# 2       Web Development with JavaScript  ubiqum-code-academy      11111
# 0            AI Programming with Python              udacity      11118
# 1                    Al Product Manager              udacity      11118
# 2                        Android Basics              udacity      11118
# 3                     Android Developer              udacity      11118
# 4               Artificial Intelligence              udacity      11118
# 5   Artificial Intelligence for Trading              udacity      11118
# 6                  Blockchain Developer              udacity      11118
# 7                    Business Analytics              udacity      11118
# 8                                   C++              udacity      11118
# 9                Cloud Dev Ops Engineer              udacity      11118
# 10                      Cloud Developer              udacity      11118
# 11                      Computer Vision              udacity      11118
# 12                         Data Analyst              udacity      11118
# 13                        Data Engineer              udacity      11118
# 14       Data Structures and Algorithms              udacity      11118
# 15                   Data Visualization              udacity      11118
# 16                        Deep Learning              udacity      11118
# 17          Deep Reinforcement Learning              udacity      11118
# 18                    Digital Marketing              udacity      11118
# 19              Front End Web Developer              udacity      11118
# 20             Full Stack Web Developer              udacity      11118
# 21     Introduction to Machine Learning              udacity      11118
# 22          Introduction to Programming              udacity      11118
# 23                        iOS Developer              udacity      11118
# 24                       Java Developer              udacity      11118
# 25            Machine Learning Engineer              udacity      11118
# 26                  Marketing Analytics              udacity      11118
# 27          Natural Language Processing              udacity      11118
# 28    Predictive Analytics for Business              udacity      11118
# 29                                React              udacity      11118
# 30           Robotics Software Engineer              udacity      11118
# 31            Self-Driving Car Engineer              udacity      11118
# 32                          UX Designer              udacity      11118
#
#                        courses by group
# 0               Data Analytics Bootcamp
# 1              Data Analytics Part-Time
# 2                 UX/UI Design Bootcamp
# 3                UX/UI Design Part-Time
# 4              Web Development Bootcamp
# 5             Web Development Part-Time
# 0                         Bootcamp Prep
# 1    Software Engineer Track: In-Person
# 2       Software Engineer Track: Online
# 0    Web Development Course - Full-Time
# 1    Web Development Course - Part-Time
# 2              Data Science - Full-Time
# 0     Data Analytics & Machine Learning
# 1             Web Development with Java
# 2       Web Development with JavaScript
# 0            AI Programming with Python
# 1                    Al Product Manager
# 2                        Android Basics
# 3                     Android Developer
# 4               Artificial Intelligence
# 5   Artificial Intelligence for Trading
# 6                  Blockchain Developer
# 7                    Business Analytics
# 8                                   C++
# 9                Cloud Dev Ops Engineer
# 10                      Cloud Developer
# 11                      Computer Vision
# 12                         Data Analyst
# 13                        Data Engineer
# 14       Data Structures and Algorithms
# 15                   Data Visualization
# 16                        Deep Learning
# 17          Deep Reinforcement Learning
# 18                    Digital Marketing
# 19              Front End Web Developer
# 20             Full Stack Web Developer
# 21     Introduction to Machine Learning
# 22          Introduction to Programming
# 23                        iOS Developer
# 24                       Java Developer
# 25            Machine Learning Engineer
# 26                  Marketing Analytics
# 27          Natural Language Processing
# 28    Predictive Analytics for Business
# 29                                React
# 30           Robotics Software Engineer
# 31            Self-Driving Car Engineer
# 32                          UX Designer

# %%
mydict
# Out:
# {'Data Analytics Bootcamp': 'data analysis/data science related course',
#  'Data Analytics Part-Time': 'data analysis/data science related course',
#  'UX/UI Design Bootcamp': 'UX/UI Design related course',
#  'UX/UI Design Part-Time': 'UX/UI Design related course',
#  'Web Development Bootcamp': 'web development related course',
#  'Web Development Part-Time': 'web development related course',
#  'Bootcamp Prep': 'other courses',
#  'Software Engineer Track: In-Person': 'web development related course',
#  'Software Engineer Track: Online': 'web development related course',
#  'Web Development Course - Full-Time': 'web development related course',
#  'Web Development Course - Part-Time': 'web development related course',
#  'Data Science - Full-Time': 'data analysis/data science related course',
#  'Data Analytics & Machine Learning': 'data analysis/data science related course',
#  'Web Development with Java': 'web development related course',
#  'Web Development with JavaScript': 'web development related course',
#  'AI Programming with Python': 'other courses',
#  'Al Product Manager': 'other courses',
#  'Android Basics': 'other courses',
#  'Android Developer': 'web development related course',
#  'Artificial Intelligence': 'other courses',
#  'Artificial Intelligence for Trading': 'other courses',
#  'Blockchain Developer': 'web development related course',
#  'Business Analytics': 'data analysis/data science related course',
#  'C++': 'other courses',
#  'Cloud Dev Ops Engineer': 'other courses',
#  'Cloud Developer': 'web development related course',
#  'Computer Vision': 'other courses',
#  'Data Analyst': 'data analysis/data science related course',
#  'Data Engineer': 'data analysis/data science related course',
#  'Data Structures and Algorithms': 'data analysis/data science related course',
#  'Data Visualization': 'data analysis/data science related course',
#  'Deep Learning': 'other courses',
#  'Deep Reinforcement Learning': 'other courses',
#  'Digital Marketing': 'other courses',
#  'Front End Web Developer': 'web development related course',
#  'Full Stack Web Developer': 'web development related course',
#  'Introduction to Machine Learning': 'other courses',
#  'Introduction to Programming': 'other courses',
#  'iOS Developer': 'web development related course',
#  'Java Developer': 'web development related course',
#  'Machine Learning Engineer': 'other courses',
#  'Marketing Analytics': 'data analysis/data science related course',
#  'Natural Language Processing': 'other courses',
#  'Predictive Analytics for Business': 'data analysis/data science related course',
#  'React': 'other courses',
#  'Robotics Software Engineer': 'web development related course',
#  'Self-Driving Car Engineer': 'other courses',
#  'UX Designer': 'UX/UI Design related course'}

# %% [markdown]
# ### Final courses table

# %%
courses['courses by group'] = courses['courses by group'].replace(mydict)
courses
# Out:
#                                 courses               school  school_id  \
# 0               Data Analytics Bootcamp             ironhack      10828
# 1              Data Analytics Part-Time             ironhack      10828
# 2                 UX/UI Design Bootcamp             ironhack      10828
# 3                UX/UI Design Part-Time             ironhack      10828
# 4              Web Development Bootcamp             ironhack      10828
# 5             Web Development Part-Time             ironhack      10828
# 0                         Bootcamp Prep          app-academy      10525
# 1    Software Engineer Track: In-Person          app-academy      10525
# 2       Software Engineer Track: Online          app-academy      10525
# 0    Web Development Course - Full-Time             le-wagon      10868
# 1    Web Development Course - Part-Time             le-wagon      10868
# 2              Data Science - Full-Time             le-wagon      10868
# 0     Data Analytics & Machine Learning  ubiqum-code-academy      11111
# 1             Web Development with Java  ubiqum-code-academy      11111
# 2       Web Development with JavaScript  ubiqum-code-academy      11111
# 0            AI Programming with Python              udacity      11118
# 1                    Al Product Manager              udacity      11118
# 2                        Android Basics              udacity      11118
# 3                     Android Developer              udacity      11118
# 4               Artificial Intelligence              udacity      11118
# 5   Artificial Intelligence for Trading              udacity      11118
# 6                  Blockchain Developer              udacity      11118
# 7                    Business Analytics              udacity      11118
# 8                                   C++              udacity      11118
# 9                Cloud Dev Ops Engineer              udacity      11118
# 10                      Cloud Developer              udacity      11118
# 11                      Computer Vision              udacity      11118
# 12                         Data Analyst              udacity      11118
# 13                        Data Engineer              udacity      11118
# 14       Data Structures and Algorithms              udacity      11118
# 15                   Data Visualization              udacity      11118
# 16                        Deep Learning              udacity      11118
# 17          Deep Reinforcement Learning              udacity      11118
# 18                    Digital Marketing              udacity      11118
# 19              Front End Web Developer              udacity      11118
# 20             Full Stack Web Developer              udacity      11118
# 21     Introduction to Machine Learning              udacity      11118
# 22          Introduction to Programming              udacity      11118
# 23                        iOS Developer              udacity      11118
# 24                       Java Developer              udacity      11118
# 25            Machine Learning Engineer              udacity      11118
# 26                  Marketing Analytics              udacity      11118
# 27          Natural Language Processing              udacity      11118
# 28    Predictive Analytics for Business              udacity      11118
# 29                                React              udacity      11118
# 30           Robotics Software Engineer              udacity      11118
# 31            Self-Driving Car Engineer              udacity      11118
# 32                          UX Designer              udacity      11118
#
#                              courses by group
# 0   data analysis/data science related course
# 1   data analysis/data science related course
# 2                 UX/UI Design related course
# 3                 UX/UI Design related course
# 4              web development related course
# 5              web development related course
# 0                               other courses
# 1              web development related course
# 2              web development related course
# 0              web development related course
# 1              web development related course
# 2   data analysis/data science related course
# 0   data analysis/data science related course
# 1              web development related course
# 2              web development related course
# 0                               other courses
# 1                               other courses
# 2                               other courses
# 3              web development related course
# 4                               other courses
# 5                               other courses
# 6              web development related course
# 7   data analysis/data science related course
# 8                               other courses
# 9                               other courses
# 10             web development related course
# 11                              other courses
# 12  data analysis/data science related course
# 13  data analysis/data science related course
# 14  data analysis/data science related course
# 15  data analysis/data science related course
# 16                              other courses
# 17                              other courses
# 18                              other courses
# 19             web development related course
# 20             web development related course
# 21                              other courses
# 22                              other courses
# 23             web development related course
# 24             web development related course
# 25                              other courses
# 26  data analysis/data science related course
# 27                              other courses
# 28  data analysis/data science related course
# 29                              other courses
# 30             web development related course
# 31                              other courses
# 32                UX/UI Design related course
